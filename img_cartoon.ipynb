# %% [markdown]
# <a href="https://colab.research.google.com/github/gowtham123-pro/inspie-implicit/blob/master/img_cartoon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files

# %%
def ReadFile(f_name):
  i=cv2.imread(f_name)
  cv2_imshow(i)
  return i

# %%
def color_quantization(img,k):
  data=np.float32(img).reshape((-1,3))
  criteria=(cv2.TERM_CRITERIA_EPS+cv2.TERM_CRITERIA_MAX_ITER,20,0.001)
  ret,label,center=cv2.kmeans(data,k,None,criteria,10,cv2.KMEANS_RANDOM_CENTERS)
  result=center[label.flatten()]
  result=result.reshape(img.shape)
  return result

# %%
def edge_mask(img,line_size,blur_value):
  gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  gray_blur=cv2.medianBlur(gray,blur_value)
  edges=cv2.adaptiveThreshold(gray_blur,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,line_size,blur_value)
  return edges

# %%
up=files.upload()
fname=next(iter(up))
img=ReadFile(fname)
# Out:
#      <input type="file" id="files-bf86c083-5c12-4e1e-acd5-04115d0de02c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf86c083-5c12-4e1e-acd5-04115d0de02c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gs.jpg to gs.jpg
# <PIL.Image.Image image mode=RGB size=1351x2026 at 0x7FC757F87518>

# %%
edges=edge_mask(img,7,7)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=1351x2026 at 0x7FC757F871D0>

# %%
img=color_quantization(img,9)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1351x2026 at 0x7FC757F87518>

# %%
blurred=cv2.bilateralFilter(img,d=7,sigmaColor=200,sigmaSpace=200)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=RGB size=1351x2026 at 0x7FC757F87470>

# %%
cartoon=cv2.bitwise_and(blurred,blurred,mask=edges)
cv2_imshow(cartoon)
# Out:
# <PIL.Image.Image image mode=RGB size=1351x2026 at 0x7FC757F87438>
